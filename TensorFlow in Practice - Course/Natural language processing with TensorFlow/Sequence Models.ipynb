# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow_datasets as tfds
import tensorflow as tf

# %%
# Get the data
dataset, info = tfds.load('imdb_reviews/subwords8k', with_info=True, as_supervised=True)
train_dataset, test_dataset = dataset['train'], dataset['test']
# Out:
# WARNING:absl:TFDS datasets with text encoding are deprecated and will be removed in a future version. Instead, you should use the plain text version and tokenize the text using `tensorflow_text` (See: https://www.tensorflow.org/tutorials/tensorflow_text/intro#tfdata_example)

# %%
tokenizer = info.features['text'].encoder

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 64

train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.padded_batch(BATCH_SIZE, tf.compat.v1.data.get_output_shapes(train_dataset))
test_dataset = test_dataset.padded_batch(BATCH_SIZE, tf.compat.v1.data.get_output_shapes(test_dataset))

# %%
type(train_dataset)
# Out:
# tensorflow.python.data.ops.dataset_ops.PaddedBatchDataset

# %% [markdown]
# # Single Layer LSTM

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer.vocab_size, 64),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 64)          523840
#
#  bidirectional (Bidirectiona  (None, 128)              66048
#  l)
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 598,209
# Trainable params: 598,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
NUM_EPOCHS = 10
history = model.fit(train_dataset, epochs=NUM_EPOCHS, validation_data=test_dataset)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 59s 142ms/step - loss: 0.5555 - accuracy: 0.7098 - val_loss: 0.4418 - val_accuracy: 0.8057
# Epoch 2/10
# 391/391 [==============================] - 55s 141ms/step - loss: 0.3669 - accuracy: 0.8533 - val_loss: 0.4084 - val_accuracy: 0.8262
# Epoch 3/10
# 391/391 [==============================] - 56s 143ms/step - loss: 0.3549 - accuracy: 0.8492 - val_loss: 0.4746 - val_accuracy: 0.8110
# Epoch 4/10
# 391/391 [==============================] - 57s 145ms/step - loss: 0.2574 - accuracy: 0.9031 - val_loss: 0.4175 - val_accuracy: 0.8235
# Epoch 5/10
# 391/391 [==============================] - 57s 147ms/step - loss: 0.2216 - accuracy: 0.9178 - val_loss: 0.4751 - val_accuracy: 0.7847
# Epoch 6/10
# 391/391 [==============================] - 57s 145ms/step - loss: 0.2003 - accuracy: 0.9285 - val_loss: 0.4817 - val_accuracy: 0.8413
# Epoch 7/10
# 391/391 [==============================] - 57s 146ms/step - loss: 0.1878 - accuracy: 0.9308 - val_loss: 0.6329 - val_accuracy: 0.6903
# Epoch 8/10
# 391/391 [==============================] - 57s 145ms/step - loss: 0.3432 - accuracy: 0.8539 - val_loss: 0.7203 - val_accuracy: 0.7450
# Epoch 9/10
# 391/391 [==============================] - 56s 144ms/step - loss: 0.3095 - accuracy: 0.8679 - val_loss: 0.6276 - val_accuracy: 0.6802
# Epoch 10/10
# 391/391 [==============================] - 58s 149ms/step - loss: 0.1986 - accuracy: 0.9247 - val_loss: 0.5364 - val_accuracy: 0.8206

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_' + string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_' + string])
    plt.show()


plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %% [markdown]
# # Multiple Layer LSTM

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer.vocab_size, 64),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
NUM_EPOCHS = 10
history = model.fit(train_dataset, epochs=NUM_EPOCHS, validation_data=test_dataset)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 64)          523840
#
#  bidirectional_1 (Bidirectio  (None, None, 128)        66048
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 64)               41216
#  nal)
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 635,329
# Trainable params: 635,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 125s 313ms/step - loss: 0.5918 - accuracy: 0.6799 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 2/10
# 391/391 [==============================] - 121s 309ms/step - loss: 0.5594 - accuracy: 0.6862 - val_loss: 0.5759 - val_accuracy: 0.7198
# Epoch 3/10
# 391/391 [==============================] - 122s 311ms/step - loss: 0.5315 - accuracy: 0.7181 - val_loss: 0.4893 - val_accuracy: 0.7721
# Epoch 4/10
# 391/391 [==============================] - 126s 322ms/step - loss: 0.4796 - accuracy: 0.7765 - val_loss: 0.5929 - val_accuracy: 0.7364
# Epoch 5/10
# 391/391 [==============================] - 124s 317ms/step - loss: 0.3817 - accuracy: 0.8393 - val_loss: 0.3899 - val_accuracy: 0.8289
# Epoch 6/10
# 391/391 [==============================] - 123s 314ms/step - loss: 0.2617 - accuracy: 0.8992 - val_loss: 0.3567 - val_accuracy: 0.8455
# Epoch 7/10
# 391/391 [==============================] - 122s 312ms/step - loss: 0.2029 - accuracy: 0.9251 - val_loss: 0.3480 - val_accuracy: 0.8586
# Epoch 8/10
# 391/391 [==============================] - 122s 312ms/step - loss: 0.1550 - accuracy: 0.9464 - val_loss: 0.3885 - val_accuracy: 0.8563
# Epoch 9/10
# 391/391 [==============================] - 121s 311ms/step - loss: 0.1179 - accuracy: 0.9600 - val_loss: 0.4778 - val_accuracy: 0.8514
# Epoch 10/10
# 391/391 [==============================] - 123s 315ms/step - loss: 0.0948 - accuracy: 0.9694 - val_loss: 0.4296 - val_accuracy: 0.8559

# %%
plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %% [markdown]
# # Multiple Layer Convolutional

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(tokenizer.vocab_size, 64),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(train_dataset, epochs=NUM_EPOCHS, validation_data=test_dataset)
plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 64)          523840
#
#  conv1d (Conv1D)             (None, None, 128)         41088
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 573,249
# Trainable params: 573,249
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 28s 67ms/step - loss: 0.4397 - accuracy: 0.7955 - val_loss: 0.3064 - val_accuracy: 0.8800
# Epoch 2/10
# 391/391 [==============================] - 10s 26ms/step - loss: 0.2223 - accuracy: 0.9174 - val_loss: 0.2973 - val_accuracy: 0.8797
# Epoch 3/10
# 391/391 [==============================] - 9s 23ms/step - loss: 0.1714 - accuracy: 0.9390 - val_loss: 0.3202 - val_accuracy: 0.8758
# Epoch 4/10
# 391/391 [==============================] - 8s 20ms/step - loss: 0.1358 - accuracy: 0.9520 - val_loss: 0.3567 - val_accuracy: 0.8705
# Epoch 5/10
# 391/391 [==============================] - 7s 18ms/step - loss: 0.1093 - accuracy: 0.9624 - val_loss: 0.4205 - val_accuracy: 0.8668
# Epoch 6/10
# 391/391 [==============================] - 7s 18ms/step - loss: 0.0912 - accuracy: 0.9698 - val_loss: 0.5111 - val_accuracy: 0.8620
# Epoch 7/10
# 391/391 [==============================] - 7s 18ms/step - loss: 0.0680 - accuracy: 0.9788 - val_loss: 0.5838 - val_accuracy: 0.8558
# Epoch 8/10
# 391/391 [==============================] - 7s 18ms/step - loss: 0.0529 - accuracy: 0.9832 - val_loss: 0.6100 - val_accuracy: 0.8560
# Epoch 9/10
# 391/391 [==============================] - 7s 18ms/step - loss: 0.0453 - accuracy: 0.9863 - val_loss: 0.6964 - val_accuracy: 0.8546
# Epoch 10/10
# 391/391 [==============================] - 7s 18ms/step - loss: 0.0336 - accuracy: 0.9906 - val_loss: 0.8791 - val_accuracy: 0.8448
